# %% [markdown]
# # EDA: Food-101 Dataset
#
# **SmartPlate | Block 1 — Computer Vision**
# **Run in:** Google Colab (CPU is fine for EDA)
#
# ## Outline
# 1. Environment setup & imports
# 2. Load Food-101 from HuggingFace Datasets
# 3. Define the 20–30 class subset
# 4. Class distribution (bar chart)
# 5. Sample images per class (grid visualization)
# 6. Image size / aspect ratio statistics
# 7. Train / validation / test split overview
# 8. Export subset to `data/raw/food101/` for training notebook
#
# ## Key Questions to Answer
# - Are classes balanced within our subset?
# - Are there quality issues (blurry, mislabeled, wrong content)?
# - What is the typical image size before ViT resizing to 224×224?
# - Which classes might be visually similar and thus harder to classify?

# %%
# Cell 1: Install dependencies (Colab only)
# !pip install datasets transformers matplotlib seaborn pillow -q

# %%
# Cell 2: Imports
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
from collections import Counter
from PIL import Image
import numpy as np

sns.set_theme(style='whitegrid')
SEED = 42

# %%
# Cell 3: Load Food-101
# TODO: Load the dataset and inspect its structure
# ds = load_dataset('food101')
# print(ds)

# %%
# Cell 4: Define 20-30 class subset
# TODO: Choose classes — consider:
#   - Coverage of healthy, moderate, unhealthy (for XGBoost balance)
#   - Visual distinctiveness (avoid very similar classes)
#   - Swiss food relevance
SELECTED_CLASSES = [
    # TODO: fill in 20-30 class names from Food-101
    # e.g. 'pizza', 'caesar_salad', 'sushi', 'hamburger', ...
]

# %%
# Cell 5: Class distribution plot
# TODO: Plot bar chart of sample count per class

# %%
# Cell 6: Sample images grid
# TODO: Show 5 sample images per class in a grid

# %%
# Cell 7: Image size statistics
# TODO: Compute and plot distribution of (width, height) before resizing

# %%
# Cell 8: Export subset
# TODO: Save filtered dataset to data/raw/food101/ with class subfolders
